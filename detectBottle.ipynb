# %%
import cv2
import numpy as np
import requests
import time
from ultralytics import YOLO

# ESP32-CAM stream URL
ip = "192.168.186.92"
esp32_cam_url = f"http://{ip}:81/stream"
model = YOLO('yolov8n.pt') 

# โหลด Haar Cascade สำหรับการตรวจจับใบหน้า

# stream = requests.get(esp32_cam_url, stream=True)

# print("starting")


def send_command(ip,command):
    ts = int(time.time() * 1000)
    url = f"http://{ip}/{command}?time={ts}"  # Timestamp as a parameter
    response = requests.get(url)

    if response.status_code == 200:
        print(f"Command '{command}' sent successfully with timestamp {ts}.")
    else:
        print(f"Error sending command: {response.status_code}")

def get_frame_img(esp32_cam_url):
  stream = requests.get(esp32_cam_url, stream=True)
  bytes = b''  # Buffer สำหรับเก็บข้อมูลที่ได้รับมาจาก stream
  for chunk in stream.iter_content(chunk_size=1024):
      # เก็บข้อมูลแต่ละ chunk ลงใน buffer
      bytes += chunk
      
      # หาเริ่มต้นและจบของ JPEG frame
      a = bytes.find(b'\xff\xd8')  # Start of JPEG
      b = bytes.find(b'\xff\xd9')  # End of JPEG
      
      # ถ้าเจอ frame JPEG ที่สมบูรณ์
      if a != -1 and b != -1:
          jpg = bytes[a:b+2]  # ดึงข้อมูล JPEG ออกมา
          bytes = bytes[b+2:]  # ลบข้อมูล JPEG ออกจาก buffer
          
          if len(jpg) > 0:
              try:
                  # แปลง JPEG เป็นภาพ
                  frame = cv2.imdecode(np.frombuffer(jpg, dtype=np.uint8), cv2.IMREAD_COLOR)
                  

                  if frame is not None:
                      # หมุนภาพ 90 องศา
                      frame = cv2.rotate(frame, cv2.ROTATE_90_CLOCKWISE)

                      return frame
              except cv2.error as e:
                  print(f"Error decoding frame: {e}")
          else:
              print("Warning: Received empty jpg frame")

    # ถ้าไม่มีการส่งข้อมูลให้กลับค่าเริ่มต้น
  return None

def find_objects(img,model):
  results = model(img)
  class_names = model.names
# Loop through the detected objects and draw bounding boxes for 'person' class (class index 0 in COCO dataset)
  for i, box in enumerate(results[0].boxes.xyxy):
      # Get bounding box coordinates (convert to int)
      x1, y1, x2, y2 = map(int, box)
      
      # Get the class index and score
      class_idx = int(results[0].boxes.cls[i])
      score = results[0].boxes.conf[i]
      # Get the class label from the class index
      label = f"{class_names[class_idx]} {score:.2f}"
      print(label,x1,y1,(x2-x1),(y2-y1))
      # Draw the bounding box
      cv2.rectangle(img, (x1, y1), (x2, y2), (0, 255, 0), 2)  # Green bounding box with thickness 2

      # Add the label for the detected object
      cv2.putText(img, label, (x1, y1 - 10), cv2.FONT_HERSHEY_SIMPLEX, 0.9, (0, 255, 0), 2)

# %%
def find_objects_id(img,model,id):
  results = model(img)
  class_names = model.names


# Loop through the detected objects and draw bounding boxes for 'person' class (class index 0 in COCO dataset)
  for i, box in enumerate(results[0].boxes.xyxy):
      # Get bounding box coordinates (convert to int)
      x1, y1, x2, y2 = map(int, box)
      w = abs(x2-x1)
      h = abs(y2-y1)
      
      # Get the class index and score
      class_idx = int(results[0].boxes.cls[i])
      print(class_idx)
      score = results[0].boxes.conf[i]
      label = f"{class_idx} {class_names[class_idx]} {score:.2f}"

      if class_idx == id:
        send_command(ip,"bling")
        # print(label)
        return w*h, x1, y1, w, h
      # Get the class label from the class index
      
  return 0,0,0,0,0

# %%
print("before while")

last_step = ""

while True:
  frame = get_frame_img(esp32_cam_url)
  a,x,y,w,h = find_objects_id(frame, model,39)
  
  print(a,x+w/2)


  if a == 0:
    if last_step == "step_go step_left":
      send_command(ip,"step_right")
    else:
      send_command(ip,"step_left")
    last_step=""

  else:
    if x+w//2 > 150:
      send_command(ip,"step_left")
      last_step = "step_left"
    elif x+w//2 < 90:
      send_command(ip,"step_right")
      last_step = "step_right"
  

  if a>0 and a<5000:
    send_command(ip,"step_go")
    last_step = "step_go "+ last_step
  time.sleep(0.2)
# Out:
# before while
#
# 0: 640x480 1 person, 23.9ms
# Speed: 3.0ms preprocess, 23.9ms inference, 2.0ms postprocess per image at shape (1, 3, 640, 480)
# 0
# 0 0.0
# Command 'step_left' sent successfully with timestamp 1725944494730.
#
# 0: 640x480 1 person, 1 bottle, 1 cup, 1 dining table, 24.5ms
# Speed: 3.0ms preprocess, 24.5ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 480)
# 0
# 39
# Command 'bling' sent successfully with timestamp 1725944495334.
# 2660 225.5
# Command 'step_left' sent successfully with timestamp 1725944495654.
# Command 'step_go' sent successfully with timestamp 1725944495858.
#
# 0: 640x480 1 cup, 25.0ms
# Speed: 2.3ms preprocess, 25.0ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 480)
# 41
# 0 0.0
# Command 'step_right' sent successfully with timestamp 1725944496669.
#
# 0: 640x480 1 person, 1 bottle, 24.5ms
# Speed: 3.0ms preprocess, 24.5ms inference, 2.0ms postprocess per image at shape (1, 3, 640, 480)
# 0
# 39
# Command 'bling' sent successfully with timestamp 1725944497473.
# 2916 201.0
# Command 'step_left' sent successfully with timestamp 1725944497703.
# Command 'step_go' sent successfully with timestamp 1725944497874.
#
# 0: 640x480 2 persons, 25.3ms
# Speed: 3.1ms preprocess, 25.3ms inference, 2.0ms postprocess per image at shape (1, 3, 640, 480)
# 0
# 0
# 0 0.0
# Command 'step_right' sent successfully with timestamp 1725944499839.
#
# 0: 640x480 1 bottle, 24.2ms
# Speed: 3.0ms preprocess, 24.2ms inference, 2.0ms postprocess per image at shape (1, 3, 640, 480)
# 39
# Command 'bling' sent successfully with timestamp 1725944500648.
# 3219 204.5
# Command 'step_left' sent successfully with timestamp 1725944500979.
# Command 'step_go' sent successfully with timestamp 1725944503337.
#
# 0: 640x480 1 person, 1 bottle, 24.5ms
# Speed: 3.0ms preprocess, 24.5ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 480)
# 39
# Command 'bling' sent successfully with timestamp 1725944504124.
# 4140 69.5
# Command 'step_right' sent successfully with timestamp 1725944504469.
# Command 'step_go' sent successfully with timestamp 1725944504665.
#
# 0: 640x480 1 bottle, 24.0ms
# Speed: 6.0ms preprocess, 24.0ms inference, 2.0ms postprocess per image at shape (1, 3, 640, 480)
# 39
# Command 'bling' sent successfully with timestamp 1725944505158.
# 4770 190.5
# Command 'step_left' sent successfully with timestamp 1725944505489.
# Command 'step_go' sent successfully with timestamp 1725944505688.
#
# 0: 640x480 1 person, 24.6ms
# Speed: 4.0ms preprocess, 24.6ms inference, 1.1ms postprocess per image at shape (1, 3, 640, 480)
# 0
# 0 0.0
# Command 'step_right' sent successfully with timestamp 1725944507239.
#
# 0: 640x480 1 bottle, 24.1ms
# Speed: 2.0ms preprocess, 24.1ms inference, 1.9ms postprocess per image at shape (1, 3, 640, 480)
# 39
# Command 'bling' sent successfully with timestamp 1725944507912.
# 5616 183.0
# Command 'step_left' sent successfully with timestamp 1725944508660.
#
# 0: 640x480 1 person, 24.4ms
# Speed: 3.1ms preprocess, 24.4ms inference, 2.0ms postprocess per image at shape (1, 3, 640, 480)
# 0
# 0 0.0
# Command 'step_left' sent successfully with timestamp 1725944510201.
#
# 0: 640x480 (no detections), 25.0ms
# Speed: 2.0ms preprocess, 25.0ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 480)
# 0 0.0
# Command 'step_left' sent successfully with timestamp 1725944511622.
#
# 0: 640x480 1 bottle, 24.5ms
# Speed: 5.3ms preprocess, 24.5ms inference, 3.0ms postprocess per image at shape (1, 3, 640, 480)
# 39
# Command 'bling' sent successfully with timestamp 1725944512276.
# 3783 229.5
# Command 'step_left' sent successfully with timestamp 1725944512551.
# Command 'step_go' sent successfully with timestamp 1725944513103.
#
# 0: 640x480 1 bottle, 24.1ms
# Speed: 3.4ms preprocess, 24.1ms inference, 2.0ms postprocess per image at shape (1, 3, 640, 480)
# 39
# Command 'bling' sent successfully with timestamp 1725944513949.
# 3978 80.5
# Command 'step_right' sent successfully with timestamp 1725944514291.
# Command 'step_go' sent successfully with timestamp 1725944514461.
#
# 0: 640x480 1 bottle, 23.9ms
# Speed: 3.0ms preprocess, 23.9ms inference, 2.0ms postprocess per image at shape (1, 3, 640, 480)
# 39
# Command 'bling' sent successfully with timestamp 1725944516615.
# 4224 233.0
# Command 'step_left' sent successfully with timestamp 1725944517061.
# Command 'step_go' sent successfully with timestamp 1725944517568.
#
# 0: 640x480 1 person, 1 bottle, 24.4ms
# Speed: 3.0ms preprocess, 24.4ms inference, 3.3ms postprocess per image at shape (1, 3, 640, 480)
# 0
# 39
# Command 'bling' sent successfully with timestamp 1725944518292.
# 5044 89.0
# Command 'step_right' sent successfully with timestamp 1725944518707.
#
# 0: 640x480 (no detections), 24.4ms
# Speed: 2.9ms preprocess, 24.4ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 480)
# 0 0.0
# Command 'step_left' sent successfully with timestamp 1725944519478.
#
# 0: 640x480 1 person, 24.5ms
# Speed: 2.1ms preprocess, 24.5ms inference, 3.0ms postprocess per image at shape (1, 3, 640, 480)
# 0
# 0 0.0
# Command 'step_left' sent successfully with timestamp 1725944520323.
#
# 0: 640x480 1 person, 25.2ms
# Speed: 2.1ms preprocess, 25.2ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 480)
# 0
# 0 0.0
# Command 'step_left' sent successfully with timestamp 1725944524104.
#
# 0: 640x480 2 persons, 24.5ms
# Speed: 3.4ms preprocess, 24.5ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 480)
# 0
# 0
# 0 0.0
# Command 'step_left' sent successfully with timestamp 1725944524838.
#
# 0: 640x480 1 person, 24.1ms
# Speed: 3.5ms preprocess, 24.1ms inference, 2.0ms postprocess per image at shape (1, 3, 640, 480)
# 0
# 0 0.0
# Command 'step_left' sent successfully with timestamp 1725944526058.
#
# 0: 640x480 3 persons, 24.1ms
# Speed: 3.0ms preprocess, 24.1ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 480)
# 0
# 0
# 0
# 0 0.0
# Command 'step_left' sent successfully with timestamp 1725944526901.
#
# 0: 640x480 1 person, 3 tvs, 24.0ms
# Speed: 2.0ms preprocess, 24.0ms inference, 2.0ms postprocess per image at shape (1, 3, 640, 480)
# 0
# 62
# 62
# 62
# 0 0.0
# Command 'step_left' sent successfully with timestamp 1725944527766.
#
# 0: 640x480 1 bottle, 1 tv, 1 laptop, 24.3ms
# Speed: 2.0ms preprocess, 24.3ms inference, 2.0ms postprocess per image at shape (1, 3, 640, 480)
# 62
# 39
# Command 'bling' sent successfully with timestamp 1725944528571.
# 1534 209.0
# Command 'step_left' sent successfully with timestamp 1725944528840.
# Command 'step_go' sent successfully with timestamp 1725944529250.
#
# 0: 640x480 1 bottle, 1 tv, 24.1ms
# Speed: 3.0ms preprocess, 24.1ms inference, 3.0ms postprocess per image at shape (1, 3, 640, 480)
# 39
# Command 'bling' sent successfully with timestamp 1725944530186.
# 2016 70.0
# Command 'step_right' sent successfully with timestamp 1725944530364.
# Command 'step_go' sent successfully with timestamp 1725944530676.
#
# 0: 640x480 1 bottle, 2 tvs, 25.0ms
# Speed: 3.0ms preprocess, 25.0ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 480)
# 62
# 62
# 39
# Command 'bling' sent successfully with timestamp 1725944531183.
# 1820 196.0
# Command 'step_left' sent successfully with timestamp 1725944531495.
# Command 'step_go' sent successfully with timestamp 1725944531751.
#
# 0: 640x480 1 bottle, 1 tv, 1 sink, 24.0ms
# Speed: 3.2ms preprocess, 24.0ms inference, 2.0ms postprocess per image at shape (1, 3, 640, 480)
# 39
# Command 'bling' sent successfully with timestamp 1725944532489.
# 2772 55.5
# Command 'step_right' sent successfully with timestamp 1725944532704.
# Command 'step_go' sent successfully with timestamp 1725944532968.
#
# 0: 640x480 1 bottle, 1 bowl, 2 tvs, 24.0ms
# Speed: 3.1ms preprocess, 24.0ms inference, 2.9ms postprocess per image at shape (1, 3, 640, 480)
# 39
# Command 'bling' sent successfully with timestamp 1725944533658.
# 2937 192.5
# Command 'step_left' sent successfully with timestamp 1725944533952.
# Command 'step_go' sent successfully with timestamp 1725944534172.
#
# 0: 640x480 1 bottle, 1 wine glass, 1 tv, 25.1ms
# Speed: 2.0ms preprocess, 25.1ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 480)
# 39
# Command 'bling' sent successfully with timestamp 1725944535078.
# 3686 49.0
# Command 'step_right' sent successfully with timestamp 1725944535386.
# Command 'step_go' sent successfully with timestamp 1725944535592.
#
# 0: 640x480 1 bottle, 2 tvs, 23.9ms
# Speed: 3.4ms preprocess, 23.9ms inference, 1.9ms postprocess per image at shape (1, 3, 640, 480)
# 39
# Command 'bling' sent successfully with timestamp 1725944536316.
# 4095 181.5
# Command 'step_left' sent successfully with timestamp 1725944536614.
# Command 'step_go' sent successfully with timestamp 1725944537024.
#
# 0: 640x480 1 bottle, 1 tv, 24.1ms
# Speed: 3.0ms preprocess, 24.1ms inference, 2.0ms postprocess per image at shape (1, 3, 640, 480)
# 39
# Command 'bling' sent successfully with timestamp 1725944537729.
# 5546 23.5
# Command 'step_right' sent successfully with timestamp 1725944538048.
#
# 0: 640x480 1 bottle, 1 tv, 25.0ms
# Speed: 2.9ms preprocess, 25.0ms inference, 2.0ms postprocess per image at shape (1, 3, 640, 480)
# 39
# Command 'bling' sent successfully with timestamp 1725944538775.
# 5060 168.0
# Command 'step_left' sent successfully with timestamp 1725944539075.
#
# 0: 640x480 1 airplane, 1 bottle, 1 tv, 24.0ms
# Speed: 2.5ms preprocess, 24.0ms inference, 3.0ms postprocess per image at shape (1, 3, 640, 480)
# 39
# Command 'bling' sent successfully with timestamp 1725944539769.
# 5499 26.5
# Command 'step_right' sent successfully with timestamp 1725944540099.
#
# 0: 640x480 1 bottle, 1 bowl, 1 tv, 24.5ms
# Speed: 3.0ms preprocess, 24.5ms inference, 2.0ms postprocess per image at shape (1, 3, 640, 480)
# 39
# Command 'bling' sent successfully with timestamp 1725944541626.
# 4945 155.5
# Command 'step_left' sent successfully with timestamp 1725944541952.
# Command 'step_go' sent successfully with timestamp 1725944542120.
#
# 0: 640x480 1 tv, 25.0ms
# Speed: 2.1ms preprocess, 25.0ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 480)
# 62
# 0 0.0
# Command 'step_right' sent successfully with timestamp 1725944543803.
#
# 0: 640x480 1 bottle, 1 tv, 24.0ms
# Speed: 3.8ms preprocess, 24.0ms inference, 2.0ms postprocess per image at shape (1, 3, 640, 480)
# 39
# Command 'bling' sent successfully with timestamp 1725944544684.
# 5781 146.5
#
# 0: 640x480 1 bottle, 1 tv, 24.4ms
# Speed: 2.0ms preprocess, 24.4ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 480)
# 39
# Command 'bling' sent successfully with timestamp 1725944545514.
# 5781 146.5
#
# 0: 640x480 1 bottle, 1 tv, 25.2ms
# Speed: 2.1ms preprocess, 25.2ms inference, 0.5ms postprocess per image at shape (1, 3, 640, 480)
# 39
# Command 'bling' sent successfully with timestamp 1725944546360.
# 5750 147.0
#
# 0: 640x480 1 bottle, 1 bowl, 1 tv, 24.0ms
# Speed: 3.0ms preprocess, 24.0ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 480)
# 39
# Command 'bling' sent successfully with timestamp 1725944546967.
# 5658 147.0
#
# 0: 640x480 1 bottle, 1 bowl, 1 refrigerator, 23.9ms
# Speed: 3.1ms preprocess, 23.9ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 480)
# 39
# Command 'bling' sent successfully with timestamp 1725944547756.
# 5405 146.5
#
# 0: 640x480 1 bottle, 1 tv, 24.6ms
# Speed: 2.9ms preprocess, 24.6ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 480)
# 39
# Command 'bling' sent successfully with timestamp 1725944549608.
# 5658 147.0
#
# 0: 640x480 1 bottle, 1 tv, 24.4ms
# Speed: 3.0ms preprocess, 24.4ms inference, 3.0ms postprocess per image at shape (1, 3, 640, 480)
# 39
# Command 'bling' sent successfully with timestamp 1725944550436.
# 5704 147.0
#
# 0: 640x480 1 bottle, 1 tv, 24.6ms
# Speed: 3.5ms preprocess, 24.6ms inference, 0.9ms postprocess per image at shape (1, 3, 640, 480)
# 39
# Command 'bling' sent successfully with timestamp 1725944551254.
# 5625 146.5
#
# 0: 640x480 1 bottle, 1 bowl, 1 tv, 24.6ms
# Speed: 3.0ms preprocess, 24.6ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 480)
# 39
# Command 'bling' sent successfully with timestamp 1725944552143.
# 5828 146.5
#
# 0: 640x480 1 bottle, 1 bowl, 1 tv, 24.8ms
# Speed: 3.0ms preprocess, 24.8ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 480)
# 39
# Command 'bling' sent successfully with timestamp 1725944558716.
# 5750 147.0
#
# 0: 640x480 1 bottle, 1 bowl, 1 tv, 24.6ms
# Speed: 2.9ms preprocess, 24.6ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 480)
# 39
# Command 'bling' sent successfully with timestamp 1725944559349.
# 5875 146.5
#
# 0: 640x480 1 bottle, 1 bowl, 1 tv, 23.3ms
# Speed: 3.0ms preprocess, 23.3ms inference, 2.0ms postprocess per image at shape (1, 3, 640, 480)
# 39
# Command 'bling' sent successfully with timestamp 1725944560154.
# 5625 146.5
#
# 0: 640x480 1 bottle, 1 tv, 24.0ms
# Speed: 4.0ms preprocess, 24.0ms inference, 2.0ms postprocess per image at shape (1, 3, 640, 480)
# 39
# Command 'bling' sent successfully with timestamp 1725944560801.
# 5796 147.0
#
# 0: 640x480 1 bottle, 1 tv, 24.8ms
# Speed: 2.0ms preprocess, 24.8ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 480)
# 39
# Command 'bling' sent successfully with timestamp 1725944561588.
# 5828 146.5
#
# 0: 640x480 1 bottle, 1 tv, 24.7ms
# Speed: 3.0ms preprocess, 24.7ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 480)
# 39
# Command 'bling' sent successfully with timestamp 1725944562230.
# 5580 146.5
#
# 0: 640x480 1 bottle, 1 tv, 24.0ms
# Speed: 2.0ms preprocess, 24.0ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 480)
# 39
# Command 'bling' sent successfully with timestamp 1725944562814.
# 5704 147.0
#
# 0: 640x480 1 bottle, 1 tv, 24.4ms
# Speed: 3.0ms preprocess, 24.4ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 480)
# 39
# Command 'bling' sent successfully with timestamp 1725944563427.
# 5875 146.5
#
# 0: 640x480 1 bottle, 1 tv, 24.4ms
# Speed: 2.1ms preprocess, 24.4ms inference, 2.0ms postprocess per image at shape (1, 3, 640, 480)
# 39
# Command 'bling' sent successfully with timestamp 1725944564258.
# 5750 147.0
#
# 0: 640x480 1 bottle, 1 tv, 24.2ms
# Speed: 2.3ms preprocess, 24.2ms inference, 2.0ms postprocess per image at shape (1, 3, 640, 480)
# 39
# Command 'bling' sent successfully with timestamp 1725944565093.
# 5750 147.0
#
# 0: 640x480 1 bottle, 1 tv, 23.9ms
# Speed: 3.0ms preprocess, 23.9ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 480)
# 39
# Command 'bling' sent successfully with timestamp 1725944565845.
# 5875 146.5
#
# 0: 640x480 1 bottle, 1 bowl, 1 tv, 25.2ms
# Speed: 2.9ms preprocess, 25.2ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 480)
# 39
# Command 'bling' sent successfully with timestamp 1725944566510.
# 5750 147.0
#
# 0: 640x480 1 bottle, 1 bowl, 24.0ms
# Speed: 3.0ms preprocess, 24.0ms inference, 3.0ms postprocess per image at shape (1, 3, 640, 480)
# 39
# Command 'bling' sent successfully with timestamp 1725944567133.
# 5750 147.0
#
# 0: 640x480 1 bottle, 1 bowl, 24.0ms
# Speed: 3.0ms preprocess, 24.0ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 480)
# 39
# Command 'bling' sent successfully with timestamp 1725944567979.
# 5625 146.5
#
# 0: 640x480 1 bottle, 1 tv, 25.0ms
# Speed: 1.9ms preprocess, 25.0ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 480)
# 39
# Command 'bling' sent successfully with timestamp 1725944568746.
# 5875 146.5
#
# 0: 640x480 1 bottle, 1 tv, 24.1ms
# Speed: 2.6ms preprocess, 24.1ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 480)
# 39
# Command 'bling' sent successfully with timestamp 1725944569402.
# 5704 147.0
#
# 0: 640x480 1 bottle, 1 tv, 24.7ms
# Speed: 3.0ms preprocess, 24.7ms inference, 2.1ms postprocess per image at shape (1, 3, 640, 480)
# 39
# Command 'bling' sent successfully with timestamp 1725944570211.
# 5828 146.5
#
# 0: 640x480 1 bottle, 25.0ms
# Speed: 5.0ms preprocess, 25.0ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 480)
# 39
# Command 'bling' sent successfully with timestamp 1725944571036.
# 5875 146.5
#
# 0: 640x480 1 bottle, 1 bowl, 1 tv, 25.0ms
# Speed: 5.3ms preprocess, 25.0ms inference, 2.0ms postprocess per image at shape (1, 3, 640, 480)
# 39
# Command 'bling' sent successfully with timestamp 1725944571899.
# 5704 147.0
#
# 0: 640x480 1 bottle, 1 tv, 23.9ms
# Speed: 3.0ms preprocess, 23.9ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 480)
# 39
# Command 'bling' sent successfully with timestamp 1725944577244.
# 5704 147.0
#
# 0: 640x480 1 bottle, 1 bowl, 1 tv, 24.0ms
# Speed: 1.9ms preprocess, 24.0ms inference, 2.0ms postprocess per image at shape (1, 3, 640, 480)
# 39
# Command 'bling' sent successfully with timestamp 1725944578114.
# 5750 147.0
#
# 0: 640x480 1 bottle, 1 tv, 25.0ms
# Speed: 3.0ms preprocess, 25.0ms inference, 2.0ms postprocess per image at shape (1, 3, 640, 480)
# 39
# Command 'bling' sent successfully with timestamp 1725944578902.
# 5922 146.5
#
# 0: 640x480 1 bottle, 1 tv, 24.0ms
# Speed: 3.0ms preprocess, 24.0ms inference, 2.0ms postprocess per image at shape (1, 3, 640, 480)
# 39
# Command 'bling' sent successfully with timestamp 1725944579525.
# 5828 146.5
#
# 0: 640x480 1 bottle, 1 tv, 24.2ms
# Speed: 2.0ms preprocess, 24.2ms inference, 3.0ms postprocess per image at shape (1, 3, 640, 480)
# 39
# Command 'bling' sent successfully with timestamp 1725944580317.
# 5750 147.0
#
# 0: 640x480 1 bottle, 1 tv, 23.7ms
# Speed: 3.0ms preprocess, 23.7ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 480)
# 39
# Command 'bling' sent successfully with timestamp 1725944581144.
# 5704 147.0
#
# 0: 640x480 1 bottle, 1 tv, 24.0ms
# Speed: 3.0ms preprocess, 24.0ms inference, 2.0ms postprocess per image at shape (1, 3, 640, 480)
# 39
# Command 'bling' sent successfully with timestamp 1725944582015.
# 5580 146.5
#
# 0: 640x480 1 bottle, 1 bowl, 24.9ms
# Speed: 2.0ms preprocess, 24.9ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 480)
# 39
# Command 'bling' sent successfully with timestamp 1725944582782.
# 5670 146.5
#
# 0: 640x480 1 bottle, 1 bowl, 1 tv, 25.1ms
# Speed: 2.1ms preprocess, 25.1ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 480)
# 39
# Command 'bling' sent successfully with timestamp 1725944583705.
# 5580 146.5
#
# 0: 640x480 1 bottle, 1 tv, 25.0ms
# Speed: 2.0ms preprocess, 25.0ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 480)
# 39
# Command 'bling' sent successfully with timestamp 1725944584525.
# 5625 146.5
#
# 0: 640x480 1 bottle, 1 bowl, 1 tv, 24.5ms
# Speed: 3.4ms preprocess, 24.5ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 480)
# 39
# Command 'bling' sent successfully with timestamp 1725944585024.
# 5658 147.0
#
# 0: 640x480 1 bottle, 1 bowl, 1 tv, 24.5ms
# Speed: 2.3ms preprocess, 24.5ms inference, 2.0ms postprocess per image at shape (1, 3, 640, 480)
# 39
# Command 'bling' sent successfully with timestamp 1725944585656.
# 5875 146.5
#
# 0: 640x480 1 bottle, 1 tv, 24.0ms
# Speed: 3.0ms preprocess, 24.0ms inference, 3.0ms postprocess per image at shape (1, 3, 640, 480)
# 39
# Command 'bling' sent successfully with timestamp 1725944586484.
# 5875 146.5
#
# 0: 640x480 1 bottle, 1 bowl, 1 tv, 23.6ms
# Speed: 3.0ms preprocess, 23.6ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 480)
# 39
# Command 'bling' sent successfully with timestamp 1725944587285.
# 5704 147.0
#
# 0: 640x480 1 bottle, 1 bowl, 1 tv, 24.4ms
# Speed: 3.0ms preprocess, 24.4ms inference, 2.0ms postprocess per image at shape (1, 3, 640, 480)
# 39
# Command 'bling' sent successfully with timestamp 1725944588171.
# 5625 146.5
#
# 0: 640x480 1 bottle, 1 bowl, 1 tv, 24.8ms
# Speed: 3.1ms preprocess, 24.8ms inference, 2.0ms postprocess per image at shape (1, 3, 640, 480)
# 39
# Command 'bling' sent successfully with timestamp 1725944588922.
# 5750 147.0
#
# 0: 640x480 1 bottle, 1 tv, 24.8ms
# Speed: 1.9ms preprocess, 24.8ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 480)
# 39
# Command 'bling' sent successfully with timestamp 1725944589739.
# 5796 147.0
#
# 0: 640x480 1 bottle, 1 tv, 24.1ms
# Speed: 2.0ms preprocess, 24.1ms inference, 2.0ms postprocess per image at shape (1, 3, 640, 480)
# 39
# Command 'bling' sent successfully with timestamp 1725944590351.
# 5704 147.0
#
# 0: 640x480 1 bottle, 1 tv, 24.5ms
# Speed: 2.4ms preprocess, 24.5ms inference, 1.5ms postprocess per image at shape (1, 3, 640, 480)
# 39
# Command 'bling' sent successfully with timestamp 1725944591169.
# 5704 147.0
#
# 0: 640x480 1 bottle, 1 tv, 24.0ms
# Speed: 3.0ms preprocess, 24.0ms inference, 2.0ms postprocess per image at shape (1, 3, 640, 480)
# 39
# Command 'bling' sent successfully with timestamp 1725944591864.
# 5781 146.5
#
# 0: 640x480 1 bottle, 1 bowl, 1 tv, 24.0ms
# Speed: 3.4ms preprocess, 24.0ms inference, 2.0ms postprocess per image at shape (1, 3, 640, 480)
# 39
# Command 'bling' sent successfully with timestamp 1725944592815.
# 5704 147.0
#
# 0: 640x480 1 bottle, 1 bowl, 1 tv, 24.1ms
# Speed: 3.0ms preprocess, 24.1ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 480)
# 39
# Command 'bling' sent successfully with timestamp 1725944593754.
# 5750 147.0
#
# 0: 640x480 1 bottle, 1 tv, 24.2ms
# Speed: 3.0ms preprocess, 24.2ms inference, 3.0ms postprocess per image at shape (1, 3, 640, 480)
# 39
# Command 'bling' sent successfully with timestamp 1725944594593.
# 5704 147.0
#
# 0: 640x480 1 bottle, 1 tv, 25.0ms
# Speed: 2.5ms preprocess, 25.0ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 480)
# 39
# Command 'bling' sent successfully with timestamp 1725944595199.
# 5704 147.0
#
# 0: 640x480 1 bottle, 1 tv, 24.5ms
# Speed: 2.0ms preprocess, 24.5ms inference, 3.0ms postprocess per image at shape (1, 3, 640, 480)
# 39
# Command 'bling' sent successfully with timestamp 1725944595795.
# 5750 147.0
#
# 0: 640x480 1 person, 1 bottle, 1 tv, 24.0ms
# Speed: 3.0ms preprocess, 24.0ms inference, 2.0ms postprocess per image at shape (1, 3, 640, 480)
# 39
# Command 'bling' sent successfully with timestamp 1725944596623.
# 5358 146.5
#
# 0: 640x480 1 bottle, 1 tv, 24.5ms
# Speed: 3.0ms preprocess, 24.5ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 480)
# 39
# Command 'bling' sent successfully with timestamp 1725944597473.
# 5875 146.5
#
# 0: 640x480 (no detections), 24.4ms
# Speed: 2.0ms preprocess, 24.4ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 480)
# 0 0.0
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[35], line 16
#      14     send_command(ip,"step_right")
#      15   else:
# ---> 16     send_command(ip,"step_left")
#      17   last_step=""
#      19 else:
#
# Cell In[21], line 22, in send_command(ip, command)
#      20 ts = int(time.time() * 1000)
#      21 url = f"http://{ip}/{command}?time={ts}"  # Timestamp as a parameter
# ---> 22 response = requests.get(url)
#      24 if response.status_code == 200:
#      25     print(f"Command '{command}' sent successfully with timestamp {ts}.")
#
# File ~\AppData\Roaming\Python\Python312\site-packages\requests\api.py:73, in get(url, params, **kwargs)
#      62 def get(url, params=None, **kwargs):
#      63     r"""Sends a GET request.
#      64
#      65     :param url: URL for the new :class:`Request` object.
#    (...)
#      70     :rtype: requests.Response
#      71     """
# ---> 73     return request("get", url, params=params, **kwargs)
#
# File ~\AppData\Roaming\Python\Python312\site-packages\requests\api.py:59, in request(method, url, **kwargs)
#      55 # By using the 'with' statement we are sure the session is closed, thus we
#      56 # avoid leaving sockets open which can trigger a ResourceWarning in some
#      57 # cases, and look like a memory leak in others.
#      58 with sessions.Session() as session:
# ---> 59     return session.request(method=method, url=url, **kwargs)
#
# File ~\AppData\Roaming\Python\Python312\site-packages\requests\sessions.py:589, in Session.request(self, method, url, params, data, headers, cookies, files, auth, timeout, allow_redirects, proxies, hooks, stream, verify, cert, json)
#     584 send_kwargs = {
#     585     "timeout": timeout,
#     586     "allow_redirects": allow_redirects,
#     587 }
#     588 send_kwargs.update(settings)
# --> 589 resp = self.send(prep, **send_kwargs)
#     591 return resp
#
# File ~\AppData\Roaming\Python\Python312\site-packages\requests\sessions.py:703, in Session.send(self, request, **kwargs)
#     700 start = preferred_clock()
#     702 # Send the request
# --> 703 r = adapter.send(request, **kwargs)
#     705 # Total elapsed time of the request (approximately)
#     706 elapsed = preferred_clock() - start
#
# File ~\AppData\Roaming\Python\Python312\site-packages\requests\adapters.py:486, in HTTPAdapter.send(self, request, stream, timeout, verify, cert, proxies)
#     483     timeout = TimeoutSauce(connect=timeout, read=timeout)
#     485 try:
# --> 486     resp = conn.urlopen(
#     487         method=request.method,
#     488         url=url,
#     489         body=request.body,
#     490         headers=request.headers,
#     491         redirect=False,
#     492         assert_same_host=False,
#     493         preload_content=False,
#     494         decode_content=False,
#     495         retries=self.max_retries,
#     496         timeout=timeout,
#     497         chunked=chunked,
#     498     )
#     500 except (ProtocolError, OSError) as err:
#     501     raise ConnectionError(err, request=request)
#
# File ~\AppData\Roaming\Python\Python312\site-packages\urllib3\connectionpool.py:793, in HTTPConnectionPool.urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, preload_content, decode_content, **response_kw)
#     790 response_conn = conn if not release_conn else None
#     792 # Make the request on the HTTPConnection object
# --> 793 response = self._make_request(
#     794     conn,
#     795     method,
#     796     url,
#     797     timeout=timeout_obj,
#     798     body=body,
#     799     headers=headers,
#     800     chunked=chunked,
#     801     retries=retries,
#     802     response_conn=response_conn,
#     803     preload_content=preload_content,
#     804     decode_content=decode_content,
#     805     **response_kw,
#     806 )
#     808 # Everything went great!
#     809 clean_exit = True
#
# File ~\AppData\Roaming\Python\Python312\site-packages\urllib3\connectionpool.py:537, in HTTPConnectionPool._make_request(self, conn, method, url, body, headers, retries, timeout, chunked, response_conn, preload_content, decode_content, enforce_content_length)
#     535 # Receive the response from the server
#     536 try:
# --> 537     response = conn.getresponse()
#     538 except (BaseSSLError, OSError) as e:
#     539     self._raise_timeout(err=e, url=url, timeout_value=read_timeout)
#
# File ~\AppData\Roaming\Python\Python312\site-packages\urllib3\connection.py:466, in HTTPConnection.getresponse(self)
#     463 from .response import HTTPResponse
#     465 # Get the response from http.client.HTTPConnection
# --> 466 httplib_response = super().getresponse()
#     468 try:
#     469     assert_header_parsing(httplib_response.msg)
#
# File c:\Program Files\Python312\Lib\http\client.py:1428, in HTTPConnection.getresponse(self)
#    1426 try:
#    1427     try:
# -> 1428         response.begin()
#    1429     except ConnectionError:
#    1430         self.close()
#
# File c:\Program Files\Python312\Lib\http\client.py:350, in HTTPResponse.begin(self)
#     347 else:
#     348     raise UnknownProtocol(version)
# --> 350 self.headers = self.msg = parse_headers(self.fp)
#     352 if self.debuglevel > 0:
#     353     for hdr, val in self.headers.items():
#
# File c:\Program Files\Python312\Lib\http\client.py:248, in parse_headers(fp, _class)
#     245 def parse_headers(fp, _class=HTTPMessage):
#     246     """Parses only RFC2822 headers from a file pointer."""
# --> 248     headers = _read_headers(fp)
#     249     return _parse_header_lines(headers, _class)
#
# File c:\Program Files\Python312\Lib\http\client.py:221, in _read_headers(fp)
#     219 headers = []
#     220 while True:
# --> 221     line = fp.readline(_MAXLINE + 1)
#     222     if len(line) > _MAXLINE:
#     223         raise LineTooLong("header line")
#
# File c:\Program Files\Python312\Lib\socket.py:707, in SocketIO.readinto(self, b)
#     705 while True:
#     706     try:
# --> 707         return self._sock.recv_into(b)
#     708     except timeout:
#     709         self._timeout_occurred = True
#
# KeyboardInterrupt:
